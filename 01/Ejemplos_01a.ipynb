# %% [markdown]
# # Tratamiento de imágenes y vídeos con OpenCV
#
# <b>Fuentes:</b>
# 1. [Tutoriales oficiales de OpenCV](https://docs.opencv.org/4.x/d6/d00/tutorial_py_root.html)
# 2. Joseph Howse and Joe Minichino, [Learning OpenCV 4 Computer Vision with Python3](https://learning-oreilly-com.bibproxy.ulpgc.es/library/view/learning-opencv-4/9781789531619/), Packt, 2020 (accesible en O'Reilly)
# 3. [OpenCV Course - Full Tutorial with Python](https://www.youtube.com/watch?v=oXlwWbU8l2o)

# %% [markdown]
# ## Gestión de imágenes y vídeos
#
# Lectura y escritura de imágenes y vídeos desde fichero y webcam.

# %%
#Lectura y Escritura de imágenes
import cv2 as cv

img = cv.imread('images/eii.png')

#cv.imwrite('images/eii2.png', img)

# %%
# lectura de imágenes
import cv2 as cv
#import numpy as np

file = 'images/eii.png'
#image = cv.imread(file) #,cv.IMREAD_GRAYSCALE)
image = cv.imread(file,cv.IMREAD_GRAYSCALE)

cv.imshow('EII', image)

k = cv.waitKey(0)

if k==ord('s'):
    print('Guardamos la imagen')
    cv.imwrite('images/eiiprueba.png', image)

cv.destroyAllWindows()

# %%
# lectura de vídeos
import cv2 as cv
video = cv.VideoCapture('videos/times-square.mp4')

while True:
    state, frame = video.read()
    
    cv.imshow('Video', frame)
    
    if cv.waitKey(20)==27:
        break

video.release()
cv.destroyAllWindows()

# %%
# lectura de webcam
import cv2 as cv

video = cv.VideoCapture(0)

while True:
    state, frame = video.read()
    
    cv.imshow('Video', frame)
    
    if cv.waitKey(20)==27:
        break

video.release()
cv.destroyAllWindows()

# %% [markdown]
# ## Dibujo de primitivas
# 1. Líneas
# 2. Rectángulos
# 3. Círculos
# 4. Elipses
# 5. Polígonos
# 6. Texto

# %%
#Dibujando primitivas
import cv2 as cv
import numpy as np

w = 300
h = 50

image = cv.imread('images/eii.png')
cv.circle(image, (w,h), 25, (0,0,255), thickness=cv.FILLED)
#cv.line(image, (0,0), (500,100), (0,255,0), thickness=4)

cv.imshow('Punto',image)
#cv.imshow('Línea',image)

cv.waitKey(0)
cv.destroyAllWindows()

# %%
#Dibujando primitivas
import cv2 as cv
import numpy as np

image = cv.imread('images/eii.png')

w = image.shape[1]//2
h = image.shape[0]//2

cv.line(image, (0,0), (w,h), (0,255,0), thickness=4)

cv.rectangle(image, (w,h), (w*2-30,h*2-30), (255,128,0), thickness=cv.FILLED)

cv.circle(image, (w,h), 50, (255,0,0), thickness=2)

cv.ellipse(image, (w//2,h),(100,50),45,0,360,(100,100,100),-1)

cv.putText(image, "Centro", (w,h), cv.FONT_HERSHEY_SIMPLEX, 1, (0,200,200), 2, cv.LINE_AA)

pts = np.array([[w+10,50],[w-25,85],[w+40,100],[w+140,80],[w+100,60]], np.int32)
print(pts)
pts = pts.reshape((-1,1,2))
print('***')
print(pts)
cv.polylines(image,[pts],True,(0,0,0),3)

cv.imshow('Primitivas',image)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# [[236  50]
#  [201  85]
#  [266 100]
#  [366  80]
#  [326  60]]
# ***
# [[[236  50]]
#
#  [[201  85]]
#
#  [[266 100]]
#
#  [[366  80]]
#
#  [[326  60]]]

# %% [markdown]
# ## Interacción con el usuario
# 1. Uso de *trackbars*
# 2. Uso del ratón

# %%
# Uso de un trackbar
import cv2 as cv

def trackbar(x):
    print(x)
    #cv.imshow('EII', img)

img = cv.imread('images/eii.png', cv.IMREAD_COLOR)
cv.imshow('EII', img)
cv.createTrackbar('x', 'EII', 100, 255, trackbar)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv

# Uso de varios Trackbars
def trackbar(x):
    x = cv.getTrackbarPos('x', 'EII')
    y = cv.getTrackbarPos('y', 'EII')
    print(x,y)
    cv.imshow('EII', img)

img = cv.imread('images/eii.png')
cv.imshow('EII', img)

cv.createTrackbar('x', 'EII', 100, 255, trackbar)
cv.createTrackbar('y', 'EII', 100, 255, trackbar)

cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv

# Uso de varios Trackbars
def nothing(x):
    pass
   
img = cv.imread('images/eii.png')
cv.imshow('EII', img)

cv.createTrackbar('x', 'EII', 100, 255, nothing)
cv.createTrackbar('y', 'EII', 100, 255, nothing)

#cv.setTrackbarPos('x', 'EII', 111)
#cv.setTrackbarPos('y', 'EII', 222)


while True:
    cv.imshow('EII', img)   
    k = cv.waitKey(1)
    if k == 27:
        break
    x = cv.getTrackbarPos('x', 'EII')
    y = cv.getTrackbarPos('y', 'EII')
    print(x,y)
    
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
 
def nothing(x):
    pass
 
# Create una imagen negra en una ventana
img = np.zeros((300,512,3), np.uint8)
cv.namedWindow('image')
 
# crear trackbars para cambio de color
cv.createTrackbar('R','image',0,255,nothing)
cv.createTrackbar('G','image',0,255,nothing)
cv.createTrackbar('B','image',0,255,nothing)
 
# crear un interruptor para funcionalidad ON/OFF
switch = '0 : OFF \n1 : ON'
cv.createTrackbar(switch, 'image',0,1,nothing)
 
while(1):
    cv.imshow('image',img)
    k = cv.waitKey(1) & 0xFF
    if k == 27:
        break
 
    # Optener estado actual de los cuatro trackbacks
    r = cv.getTrackbarPos('R','image')
    g = cv.getTrackbarPos('G','image')
    b = cv.getTrackbarPos('B','image')
    s = cv.getTrackbarPos(switch,'image')
 
    if s == 0:
        img[:] = 0
    else:
        img[:] = [b,g,r]
 
cv.destroyAllWindows()

# %%
# Uso del ratón
import cv2 as cv
import numpy as np

def mouse(event, x, y, flags, param):
    text = f'{event} - ({x}, {y}), flags={flags}, param={param}'
    print(text)
    if flags==1:
        #img[y-1,x]=[255,0,0]
        #img[y,x]  =[255,0,0]
        #img[y+1,x]=[255,0,0]
        #img[y,x-1]=[255,0,0]
        #img[y,x+1]=[255,0,0]
        
        img[y-1,x]=[0,255,0]
        img[y,x]  =[0,255,0]
        img[y+1,x]=[0,255,0]
        img[y,x-1]=[0,255,0]
        img[y,x+1]=[0,255,0]
     
        #img[y-1,x]=[0,0,255]
        #img[y,x]  =[0,0,255]
        #img[y+1,x]=[0,0,255]
        #img[y,x-1]=[0,0,255]
        #img[y,x+1]=[0,0,255]
        
    cv.imshow('EII', img)

img = cv.imread('images/eii.png')
#img = 255*np.ones((480,640,3), np.uint8)

cv.imshow('EII', img)

cv.setMouseCallback('EII', mouse)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 0 - (121, 13), flags=0, param=None
# 0 - (161, 52), flags=0, param=None
# 0 - (213, 94), flags=0, param=None
# 0 - (272, 131), flags=0, param=None
# 0 - (278, 134), flags=0, param=None
# 0 - (301, 146), flags=0, param=None
# 0 - (303, 147), flags=0, param=None
# 0 - (309, 149), flags=0, param=None
# 0 - (311, 150), flags=0, param=None
# 0 - (313, 151), flags=0, param=None
# 0 - (313, 152), flags=0, param=None
# 0 - (314, 153), flags=0, param=None
# 0 - (314, 154), flags=0, param=None
# 0 - (315, 155), flags=0, param=None
# 0 - (315, 157), flags=0, param=None
# 0 - (315, 160), flags=0, param=None
# 0 - (316, 163), flags=0, param=None
# 0 - (316, 166), flags=0, param=None
# 0 - (316, 167), flags=0, param=None
# 0 - (315, 171), flags=0, param=None
# 0 - (312, 173), flags=0, param=None
# 0 - (307, 176), flags=0, param=None
# 0 - (306, 176), flags=0, param=None
# 0 - (296, 180), flags=0, param=None
# 0 - (294, 180), flags=0, param=None
# 0 - (282, 185), flags=0, param=None
# 0 - (281, 186), flags=0, param=None
# 0 - (270, 190), flags=0, param=None
# 0 - (260, 195), flags=0, param=None
# 0 - (260, 196), flags=0, param=None
# 0 - (254, 198), flags=0, param=None
# 0 - (253, 198), flags=0, param=None
# 0 - (252, 198), flags=0, param=None
# 0 - (251, 197), flags=0, param=None
# 0 - (250, 195), flags=0, param=None
# 0 - (249, 192), flags=0, param=None
# 0 - (249, 189), flags=0, param=None
# 0 - (249, 187), flags=0, param=None
# 1 - (249, 187), flags=1, param=None
# 0 - (251, 187), flags=1, param=None
# 0 - (254, 185), flags=1, param=None
# 0 - (260, 182), flags=1, param=None
# 0 - (261, 181), flags=1, param=None
# 0 - (263, 180), flags=1, param=None
# 0 - (270, 175), flags=1, param=None
# 0 - (277, 170), flags=1, param=None
# 0 - (279, 169), flags=1, param=None
# 0 - (286, 164), flags=1, param=None
# 0 - (288, 163), flags=1, param=None
# 0 - (289, 162), flags=1, param=None
# 0 - (291, 161), flags=1, param=None
# 0 - (302, 153), flags=1, param=None
# 0 - (311, 147), flags=1, param=None
# 0 - (312, 146), flags=1, param=None
# 0 - (314, 145), flags=1, param=None
# 0 - (326, 137), flags=1, param=None
# 0 - (338, 129), flags=1, param=None
# 0 - (349, 120), flags=1, param=None
# 0 - (350, 119), flags=1, param=None
# 0 - (358, 113), flags=1, param=None
# 0 - (358, 112), flags=1, param=None
# 0 - (362, 108), flags=1, param=None
# 0 - (368, 104), flags=1, param=None
# 0 - (372, 101), flags=1, param=None
# 0 - (373, 99), flags=1, param=None
# 0 - (373, 98), flags=1, param=None
# 0 - (374, 98), flags=1, param=None
# 0 - (372, 99), flags=1, param=None
# 0 - (368, 99), flags=1, param=None
# 0 - (362, 99), flags=1, param=None
# 0 - (351, 99), flags=1, param=None
# 0 - (341, 99), flags=1, param=None
# 0 - (339, 99), flags=1, param=None
# 0 - (330, 99), flags=1, param=None
# 0 - (329, 99), flags=1, param=None
# 0 - (323, 99), flags=1, param=None
# 0 - (322, 99), flags=1, param=None
# 0 - (321, 99), flags=1, param=None
# 0 - (319, 98), flags=1, param=None
# 0 - (318, 98), flags=1, param=None
# 0 - (317, 98), flags=1, param=None
# 0 - (317, 97), flags=1, param=None
# 4 - (317, 97), flags=1, param=None
# 0 - (316, 96), flags=0, param=None
# 0 - (315, 95), flags=0, param=None
# 0 - (312, 93), flags=0, param=None
# 0 - (307, 91), flags=0, param=None
# 0 - (299, 90), flags=0, param=None
# 0 - (287, 88), flags=0, param=None
# 0 - (275, 88), flags=0, param=None
# 0 - (259, 87), flags=0, param=None
# 0 - (244, 87), flags=0, param=None
# 0 - (233, 87), flags=0, param=None
# 0 - (221, 87), flags=0, param=None
# 0 - (209, 87), flags=0, param=None
# 0 - (199, 87), flags=0, param=None
# 0 - (187, 87), flags=0, param=None
# 0 - (178, 86), flags=0, param=None
# 0 - (169, 86), flags=0, param=None
# 0 - (164, 86), flags=0, param=None
# 0 - (163, 86), flags=0, param=None
# 0 - (162, 86), flags=0, param=None
# 1 - (162, 86), flags=1, param=None
# 0 - (161, 87), flags=1, param=None
# 0 - (160, 89), flags=1, param=None
# 0 - (159, 91), flags=1, param=None
# 0 - (159, 92), flags=1, param=None
# 0 - (158, 92), flags=1, param=None
# 0 - (156, 95), flags=1, param=None
# 0 - (152, 99), flags=1, param=None
# 0 - (147, 106), flags=1, param=None
# 0 - (143, 112), flags=1, param=None
# 0 - (140, 116), flags=1, param=None
# 0 - (139, 117), flags=1, param=None
# 0 - (139, 118), flags=1, param=None
# 0 - (136, 122), flags=1, param=None
# 0 - (134, 127), flags=1, param=None
# 0 - (133, 127), flags=1, param=None
# 0 - (132, 131), flags=1, param=None
# 0 - (130, 134), flags=1, param=None
# 0 - (129, 136), flags=1, param=None
# 0 - (128, 138), flags=1, param=None
# 0 - (128, 139), flags=1, param=None
# 0 - (126, 140), flags=1, param=None
# 0 - (125, 141), flags=1, param=None
# 0 - (124, 142), flags=1, param=None
# 0 - (123, 143), flags=1, param=None
# 0 - (121, 143), flags=1, param=None
# 0 - (119, 142), flags=1, param=None
# 0 - (118, 142), flags=1, param=None
# 0 - (116, 140), flags=1, param=None
# 0 - (113, 138), flags=1, param=None
# 0 - (112, 136), flags=1, param=None
# 0 - (112, 134), flags=1, param=None
# 0 - (111, 132), flags=1, param=None
# 0 - (111, 130), flags=1, param=None
# 0 - (111, 128), flags=1, param=None
# 0 - (111, 125), flags=1, param=None
# 0 - (111, 121), flags=1, param=None
# 0 - (111, 119), flags=1, param=None
# 0 - (111, 116), flags=1, param=None
# 0 - (112, 115), flags=1, param=None
# 0 - (112, 113), flags=1, param=None
# 0 - (113, 110), flags=1, param=None
# 0 - (115, 107), flags=1, param=None
# 0 - (116, 106), flags=1, param=None
# 0 - (117, 104), flags=1, param=None
# 0 - (119, 103), flags=1, param=None
# 0 - (120, 102), flags=1, param=None
# 0 - (121, 102), flags=1, param=None
# 0 - (123, 102), flags=1, param=None
# 0 - (125, 100), flags=1, param=None
# 0 - (129, 99), flags=1, param=None
# 0 - (130, 99), flags=1, param=None
# 0 - (136, 99), flags=1, param=None
# 0 - (141, 99), flags=1, param=None
# 0 - (142, 99), flags=1, param=None
# 0 - (148, 99), flags=1, param=None
# 0 - (149, 99), flags=1, param=None
# 0 - (154, 99), flags=1, param=None
# 0 - (159, 100), flags=1, param=None
# 0 - (159, 101), flags=1, param=None
# 0 - (160, 101), flags=1, param=None
# 0 - (160, 102), flags=1, param=None
# 0 - (161, 102), flags=1, param=None
# 0 - (161, 103), flags=1, param=None
# 0 - (161, 104), flags=1, param=None
# 0 - (161, 105), flags=1, param=None
# 0 - (161, 106), flags=1, param=None
# 4 - (161, 106), flags=1, param=None
# 0 - (161, 107), flags=0, param=None
# 0 - (161, 110), flags=0, param=None
# 0 - (161, 111), flags=0, param=None
# 0 - (160, 114), flags=0, param=None
# 0 - (157, 120), flags=0, param=None
# 0 - (157, 129), flags=0, param=None
# 0 - (157, 139), flags=0, param=None
# 0 - (160, 145), flags=0, param=None
# 0 - (162, 150), flags=0, param=None
# 0 - (166, 154), flags=0, param=None
# 0 - (169, 159), flags=0, param=None
# 0 - (172, 163), flags=0, param=None
# 0 - (175, 166), flags=0, param=None
# 0 - (179, 169), flags=0, param=None
# 0 - (182, 171), flags=0, param=None
# 0 - (183, 171), flags=0, param=None
# 0 - (186, 173), flags=0, param=None
# 0 - (188, 174), flags=0, param=None
# 0 - (189, 174), flags=0, param=None
# 0 - (191, 175), flags=0, param=None
# 0 - (193, 175), flags=0, param=None
# 0 - (194, 175), flags=0, param=None
# 0 - (195, 175), flags=0, param=None
# 0 - (196, 176), flags=0, param=None
# 0 - (197, 176), flags=0, param=None
# 0 - (198, 177), flags=0, param=None
# 0 - (198, 178), flags=0, param=None
# 1 - (198, 178), flags=1, param=None
# 0 - (199, 178), flags=1, param=None
# 0 - (200, 179), flags=1, param=None
# 0 - (201, 180), flags=1, param=None
# 0 - (202, 180), flags=1, param=None
# 0 - (204, 182), flags=1, param=None
# 0 - (207, 183), flags=1, param=None
# 0 - (213, 186), flags=1, param=None
# 0 - (221, 189), flags=1, param=None
# 0 - (232, 192), flags=1, param=None
# 0 - (244, 196), flags=1, param=None
# 0 - (254, 198), flags=1, param=None
# 0 - (256, 199), flags=1, param=None
# 0 - (263, 201), flags=1, param=None
# 0 - (265, 202), flags=1, param=None
# 0 - (266, 202), flags=1, param=None
# 0 - (265, 202), flags=1, param=None
# 0 - (264, 202), flags=1, param=None
# 0 - (262, 202), flags=1, param=None
# 0 - (260, 203), flags=1, param=None
# 0 - (259, 203), flags=1, param=None
# 0 - (259, 204), flags=1, param=None
# 0 - (258, 204), flags=1, param=None
# 0 - (258, 206), flags=1, param=None
# 0 - (257, 207), flags=1, param=None
# 0 - (256, 208), flags=1, param=None
# 0 - (255, 210), flags=1, param=None
# 0 - (251, 213), flags=1, param=None
# 0 - (246, 217), flags=1, param=None
# 0 - (240, 222), flags=1, param=None
# 0 - (230, 228), flags=1, param=None
# 0 - (220, 235), flags=1, param=None
# 0 - (206, 241), flags=1, param=None
# 0 - (194, 247), flags=1, param=None
# 0 - (184, 251), flags=1, param=None
# 0 - (177, 252), flags=1, param=None
# 0 - (172, 253), flags=1, param=None
# 0 - (171, 253), flags=1, param=None
# 0 - (170, 253), flags=1, param=None
# 0 - (169, 253), flags=1, param=None
# 0 - (167, 251), flags=1, param=None
# 0 - (166, 250), flags=1, param=None
# 0 - (164, 249), flags=1, param=None
# 0 - (162, 246), flags=1, param=None
# 0 - (160, 242), flags=1, param=None
# 0 - (158, 240), flags=1, param=None
# 0 - (158, 239), flags=1, param=None
# 0 - (157, 238), flags=1, param=None
# 0 - (153, 232), flags=1, param=None
# 0 - (150, 228), flags=1, param=None
# 0 - (150, 225), flags=1, param=None
# 0 - (149, 225), flags=1, param=None
# 0 - (149, 226), flags=1, param=None
# 0 - (149, 228), flags=1, param=None
# 4 - (149, 228), flags=1, param=None
# 0 - (148, 232), flags=0, param=None
# 0 - (148, 238), flags=0, param=None
# 0 - (145, 246), flags=0, param=None
# 0 - (145, 248), flags=0, param=None
# 0 - (143, 253), flags=0, param=None
# 0 - (142, 261), flags=0, param=None
# 0 - (141, 268), flags=0, param=None
# 0 - (140, 275), flags=0, param=None
# 0 - (139, 282), flags=0, param=None
# 0 - (139, 286), flags=0, param=None
# 0 - (139, 290), flags=0, param=None
# 0 - (139, 291), flags=0, param=None
# 0 - (139, 295), flags=0, param=None
# 0 - (140, 299), flags=0, param=None
# 0 - (140, 301), flags=0, param=None
# 0 - (141, 301), flags=0, param=None
# 1 - (141, 301), flags=1, param=None
# 0 - (142, 302), flags=1, param=None
# 0 - (146, 302), flags=1, param=None
# 0 - (154, 302), flags=1, param=None
# 0 - (155, 302), flags=1, param=None
# 0 - (169, 302), flags=1, param=None
# 0 - (177, 301), flags=1, param=None
# 0 - (181, 298), flags=1, param=None
# 0 - (186, 296), flags=1, param=None
# 0 - (186, 295), flags=1, param=None
# 0 - (190, 292), flags=1, param=None
# 0 - (191, 292), flags=1, param=None
# 0 - (194, 289), flags=1, param=None
# 0 - (198, 287), flags=1, param=None
# 0 - (199, 286), flags=1, param=None
# 0 - (204, 282), flags=1, param=None
# 0 - (210, 279), flags=1, param=None
# 0 - (215, 276), flags=1, param=None
# 0 - (220, 273), flags=1, param=None
# 0 - (226, 270), flags=1, param=None
# 0 - (230, 267), flags=1, param=None
# 0 - (235, 264), flags=1, param=None
# 0 - (239, 262), flags=1, param=None
# 0 - (244, 259), flags=1, param=None
# 0 - (245, 259), flags=1, param=None
# 0 - (248, 256), flags=1, param=None
# 0 - (249, 256), flags=1, param=None
# 0 - (252, 254), flags=1, param=None
# 0 - (256, 251), flags=1, param=None
# 0 - (259, 249), flags=1, param=None
# 0 - (263, 246), flags=1, param=None
# 0 - (265, 244), flags=1, param=None
# 0 - (268, 243), flags=1, param=None
# 0 - (269, 242), flags=1, param=None
# 0 - (270, 242), flags=1, param=None
# 0 - (271, 242), flags=1, param=None
# 0 - (272, 244), flags=1, param=None
# 0 - (272, 245), flags=1, param=None
# 0 - (273, 247), flags=1, param=None
# 0 - (274, 250), flags=1, param=None
# 0 - (274, 253), flags=1, param=None
# 0 - (275, 254), flags=1, param=None
# 0 - (276, 253), flags=1, param=None
# 0 - (276, 251), flags=1, param=None
# 0 - (277, 249), flags=1, param=None
# 0 - (278, 245), flags=1, param=None
# 0 - (279, 245), flags=1, param=None
# 0 - (280, 244), flags=1, param=None
# 0 - (280, 243), flags=1, param=None
# 0 - (282, 241), flags=1, param=None
# 0 - (283, 240), flags=1, param=None
# 0 - (287, 236), flags=1, param=None
# 0 - (287, 235), flags=1, param=None
# 0 - (288, 235), flags=1, param=None
# 0 - (288, 234), flags=1, param=None
# 0 - (289, 233), flags=1, param=None
# 0 - (297, 226), flags=1, param=None
# 0 - (297, 225), flags=1, param=None
# 0 - (299, 224), flags=1, param=None
# 0 - (302, 221), flags=1, param=None
# 0 - (303, 220), flags=1, param=None
# 0 - (307, 216), flags=1, param=None
# 0 - (307, 215), flags=1, param=None
# 0 - (309, 214), flags=1, param=None
# 0 - (311, 211), flags=1, param=None
# 0 - (313, 210), flags=1, param=None
# 0 - (315, 207), flags=1, param=None
# 0 - (316, 207), flags=1, param=None
# 0 - (316, 206), flags=1, param=None
# 0 - (317, 206), flags=1, param=None
# 0 - (318, 205), flags=1, param=None
# 0 - (319, 204), flags=1, param=None
# 0 - (320, 202), flags=1, param=None
# 0 - (322, 201), flags=1, param=None
# 0 - (323, 201), flags=1, param=None
# 4 - (323, 201), flags=1, param=None
# 0 - (324, 201), flags=0, param=None
# 0 - (324, 202), flags=0, param=None
# 0 - (325, 203), flags=0, param=None
# 0 - (326, 203), flags=0, param=None
# 0 - (326, 204), flags=0, param=None
# 0 - (327, 205), flags=0, param=None
# 0 - (328, 205), flags=0, param=None
# 0 - (328, 206), flags=0, param=None
# 0 - (330, 206), flags=0, param=None
# 0 - (336, 206), flags=0, param=None
# 0 - (355, 201), flags=0, param=None
# 0 - (388, 195), flags=0, param=None
# 0 - (442, 193), flags=0, param=None
# 0 - (439, 273), flags=0, param=None
# 0 - (438, 272), flags=0, param=None
# 0 - (431, 269), flags=0, param=None
# 0 - (427, 267), flags=0, param=None
# 0 - (426, 267), flags=0, param=None
# 0 - (419, 263), flags=0, param=None
# 0 - (412, 259), flags=0, param=None
# 0 - (410, 257), flags=0, param=None
# 0 - (401, 253), flags=0, param=None
# 0 - (389, 246), flags=0, param=None
# 0 - (379, 240), flags=0, param=None
# 0 - (370, 233), flags=0, param=None
# 0 - (366, 228), flags=0, param=None
# 0 - (363, 225), flags=0, param=None
# 0 - (361, 223), flags=0, param=None
# 0 - (358, 219), flags=0, param=None
# 0 - (354, 215), flags=0, param=None
# 0 - (344, 209), flags=0, param=None
# 0 - (333, 202), flags=0, param=None
# 0 - (328, 198), flags=0, param=None
# 0 - (328, 197), flags=0, param=None
# 0 - (327, 197), flags=0, param=None
# 0 - (327, 196), flags=0, param=None
# 2 - (327, 196), flags=2, param=None
# 0 - (328, 199), flags=2, param=None
# 0 - (331, 201), flags=2, param=None
# 0 - (333, 204), flags=2, param=None
# 0 - (336, 207), flags=2, param=None
# 0 - (338, 210), flags=2, param=None
# 0 - (340, 212), flags=2, param=None
# 0 - (341, 214), flags=2, param=None
# 0 - (342, 216), flags=2, param=None
# 0 - (343, 218), flags=2, param=None
# 0 - (343, 219), flags=2, param=None
# 0 - (344, 221), flags=2, param=None
# 0 - (345, 225), flags=2, param=None
# 0 - (345, 229), flags=2, param=None
# 0 - (346, 233), flags=2, param=None
# 0 - (347, 237), flags=2, param=None
# 0 - (347, 241), flags=2, param=None
# 0 - (347, 245), flags=2, param=None
# 0 - (347, 246), flags=2, param=None
# 0 - (347, 249), flags=2, param=None
# 0 - (347, 250), flags=2, param=None
# 0 - (347, 251), flags=2, param=None
# 0 - (347, 252), flags=2, param=None
# 0 - (347, 254), flags=2, param=None
# 0 - (347, 255), flags=2, param=None
# 0 - (347, 256), flags=2, param=None
# 0 - (347, 257), flags=2, param=None
# 0 - (347, 258), flags=2, param=None
# 0 - (346, 259), flags=2, param=None
# 0 - (344, 263), flags=2, param=None
# 0 - (343, 263), flags=2, param=None
# 0 - (340, 267), flags=2, param=None
# 0 - (337, 271), flags=2, param=None
# 0 - (336, 271), flags=2, param=None
# 0 - (334, 273), flags=2, param=None
# 0 - (333, 274), flags=2, param=None
# 0 - (333, 275), flags=2, param=None
# 0 - (332, 275), flags=2, param=None
# 0 - (331, 277), flags=2, param=None
# 0 - (330, 277), flags=2, param=None
# 0 - (330, 278), flags=2, param=None
# 0 - (329, 278), flags=2, param=None
# 1 - (329, 278), flags=3, param=None
# 0 - (329, 279), flags=3, param=None
# 0 - (329, 280), flags=3, param=None
# 0 - (329, 281), flags=3, param=None
# 0 - (329, 282), flags=3, param=None
# 0 - (329, 283), flags=3, param=None
# 4 - (329, 283), flags=3, param=None
# 5 - (329, 283), flags=2, param=None
# 1 - (370, 249), flags=1, param=None
# 0 - (370, 248), flags=1, param=None
# 0 - (370, 247), flags=1, param=None
# 0 - (370, 246), flags=1, param=None
# 0 - (370, 244), flags=1, param=None
# 0 - (370, 243), flags=1, param=None
# 0 - (370, 242), flags=1, param=None
# 0 - (370, 240), flags=1, param=None
# 0 - (370, 238), flags=1, param=None
# 0 - (369, 235), flags=1, param=None
# 0 - (369, 234), flags=1, param=None
# 0 - (369, 232), flags=1, param=None
# 0 - (369, 230), flags=1, param=None
# 0 - (369, 228), flags=1, param=None
# 0 - (369, 225), flags=1, param=None
# 0 - (369, 221), flags=1, param=None
# 0 - (370, 218), flags=1, param=None
# 0 - (371, 214), flags=1, param=None
# 0 - (372, 210), flags=1, param=None
# 0 - (372, 209), flags=1, param=None
# 0 - (372, 205), flags=1, param=None
# 0 - (373, 201), flags=1, param=None
# 0 - (373, 198), flags=1, param=None
# 0 - (373, 195), flags=1, param=None
# 0 - (373, 194), flags=1, param=None
# 0 - (373, 190), flags=1, param=None
# 0 - (373, 188), flags=1, param=None
# 0 - (373, 185), flags=1, param=None
# 0 - (373, 184), flags=1, param=None
# 0 - (373, 183), flags=1, param=None
# 0 - (373, 182), flags=1, param=None
# 0 - (373, 181), flags=1, param=None
# 0 - (373, 180), flags=1, param=None
# 0 - (373, 179), flags=1, param=None
# 0 - (372, 179), flags=1, param=None
# 0 - (372, 177), flags=1, param=None
# 0 - (371, 176), flags=1, param=None
# 0 - (370, 173), flags=1, param=None
# 0 - (367, 170), flags=1, param=None
# 0 - (363, 166), flags=1, param=None
# 0 - (362, 164), flags=1, param=None
# 0 - (360, 163), flags=1, param=None
# 0 - (358, 162), flags=1, param=None
# 0 - (356, 160), flags=1, param=None
# 0 - (355, 160), flags=1, param=None
# 0 - (354, 160), flags=1, param=None
# 0 - (353, 160), flags=1, param=None
# 0 - (353, 159), flags=1, param=None
# 0 - (352, 159), flags=1, param=None
# 0 - (351, 159), flags=1, param=None
# 0 - (350, 159), flags=1, param=None
# 4 - (350, 159), flags=1, param=None
# 1 - (350, 159), flags=1, param=None
# 0 - (350, 161), flags=1, param=None
# 0 - (351, 166), flags=1, param=None
# 0 - (354, 187), flags=1, param=None
# 0 - (354, 189), flags=1, param=None
# 0 - (358, 212), flags=1, param=None
# 0 - (358, 213), flags=1, param=None
# 0 - (361, 241), flags=1, param=None
# 0 - (363, 252), flags=1, param=None
# 0 - (365, 261), flags=1, param=None
# 0 - (365, 271), flags=1, param=None
# 0 - (365, 279), flags=1, param=None
# 0 - (366, 288), flags=1, param=None
# 0 - (366, 289), flags=1, param=None
# 0 - (366, 297), flags=1, param=None
# 0 - (366, 298), flags=1, param=None
# 0 - (367, 307), flags=1, param=None
# 0 - (367, 308), flags=1, param=None
# 0 - (367, 318), flags=1, param=None
# 0 - (367, 328), flags=1, param=None
# 0 - (367, 340), flags=1, param=None
# 0 - (366, 349), flags=1, param=None
# 0 - (365, 354), flags=1, param=None
# 0 - (365, 358), flags=1, param=None
# 0 - (364, 361), flags=1, param=None
# 0 - (363, 362), flags=1, param=None
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 17, in mouse(event, x, y, flags, param)
#      15 img[y-1,x]=[0,255,0]
#      16 img[y,x]  =[0,255,0]
# ---> 17 img[y+1,x]=[0,255,0]
#      18 img[y,x-1]=[0,255,0]
#      19 img[y,x+1]=[0,255,0]
#
# IndexError: index 363 is out of bounds for axis 0 with size 363
# 0 - (361, 366), flags=1, param=None
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 15, in mouse(event, x, y, flags, param)
#       7 print(text)
#       8 if flags==1:
#       9     #img[y-1,x]=[255,0,0]
#      10     #img[y,x]  =[255,0,0]
#      11     #img[y+1,x]=[255,0,0]
#      12     #img[y,x-1]=[255,0,0]
#      13     #img[y,x+1]=[255,0,0]
# ---> 15     img[y-1,x]=[0,255,0]
#      16     img[y,x]  =[0,255,0]
#      17     img[y+1,x]=[0,255,0]
#
# IndexError: index 365 is out of bounds for axis 0 with size 363
# 4 - (361, 366), flags=1, param=None
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 15, in mouse(event, x, y, flags, param)
#       7 print(text)
#       8 if flags==1:
#       9     #img[y-1,x]=[255,0,0]
#      10     #img[y,x]  =[255,0,0]
#      11     #img[y+1,x]=[255,0,0]
#      12     #img[y,x-1]=[255,0,0]
#      13     #img[y,x+1]=[255,0,0]
# ---> 15     img[y-1,x]=[0,255,0]
#      16     img[y,x]  =[0,255,0]
#      17     img[y+1,x]=[0,255,0]
#
# IndexError: index 365 is out of bounds for axis 0 with size 363
# 0 - (356, 362), flags=0, param=None
# 0 - (355, 361), flags=0, param=None
# 0 - (355, 360), flags=0, param=None
# 0 - (354, 358), flags=0, param=None
# 0 - (353, 357), flags=0, param=None
# 0 - (353, 354), flags=0, param=None
# 0 - (369, 345), flags=0, param=None
# 0 - (374, 342), flags=0, param=None
# 0 - (380, 341), flags=0, param=None
# 0 - (430, 333), flags=0, param=None
# 0 - (448, 245), flags=0, param=None
# 0 - (442, 243), flags=0, param=None
# 0 - (437, 240), flags=0, param=None
# 0 - (433, 238), flags=0, param=None
# 0 - (416, 229), flags=0, param=None
# 0 - (402, 221), flags=0, param=None
# 0 - (396, 217), flags=0, param=None
# 0 - (396, 216), flags=0, param=None
# 0 - (394, 213), flags=0, param=None
# 0 - (393, 208), flags=0, param=None
# 0 - (392, 207), flags=0, param=None
# 0 - (392, 203), flags=0, param=None
# 0 - (391, 199), flags=0, param=None
# 0 - (390, 196), flags=0, param=None
# 0 - (390, 195), flags=0, param=None
# 0 - (390, 192), flags=0, param=None
# 0 - (390, 189), flags=0, param=None
# 0 - (390, 185), flags=0, param=None
# 0 - (390, 182), flags=0, param=None
# 0 - (391, 181), flags=0, param=None
# 0 - (391, 180), flags=0, param=None
# 0 - (391, 178), flags=0, param=None
# 0 - (392, 176), flags=0, param=None
# 0 - (393, 174), flags=0, param=None
# 0 - (393, 172), flags=0, param=None
# 0 - (393, 171), flags=0, param=None
# 0 - (395, 169), flags=0, param=None
# 0 - (396, 165), flags=0, param=None
# 0 - (397, 164), flags=0, param=None
# 0 - (397, 163), flags=0, param=None
# 0 - (398, 162), flags=0, param=None
# 0 - (399, 161), flags=0, param=None
# 1 - (399, 161), flags=1, param=None
# 0 - (401, 162), flags=1, param=None
# 0 - (403, 164), flags=1, param=None
# 0 - (404, 166), flags=1, param=None
# 0 - (405, 168), flags=1, param=None
# 0 - (406, 171), flags=1, param=None
# 0 - (406, 176), flags=1, param=None
# 0 - (406, 183), flags=1, param=None
# 0 - (405, 195), flags=1, param=None
# 0 - (403, 203), flags=1, param=None
# 0 - (400, 212), flags=1, param=None
# 0 - (395, 222), flags=1, param=None
# 0 - (391, 231), flags=1, param=None
# 0 - (387, 237), flags=1, param=None
# 0 - (384, 241), flags=1, param=None
# 0 - (381, 245), flags=1, param=None
# 0 - (379, 248), flags=1, param=None
# 0 - (375, 250), flags=1, param=None
# 0 - (374, 250), flags=1, param=None
# 0 - (372, 252), flags=1, param=None
# 0 - (371, 252), flags=1, param=None
# 0 - (370, 253), flags=1, param=None
# 0 - (369, 253), flags=1, param=None
# 0 - (367, 253), flags=1, param=None
# 0 - (367, 254), flags=1, param=None
# 0 - (366, 254), flags=1, param=None
# 0 - (365, 254), flags=1, param=None
# 0 - (363, 254), flags=1, param=None
# 0 - (362, 254), flags=1, param=None
# 0 - (361, 254), flags=1, param=None
# 0 - (359, 254), flags=1, param=None
# 0 - (358, 254), flags=1, param=None
# 0 - (357, 253), flags=1, param=None
# 0 - (356, 253), flags=1, param=None
# 4 - (356, 253), flags=1, param=None
# 0 - (355, 253), flags=0, param=None
# 0 - (346, 257), flags=0, param=None
# 0 - (341, 258), flags=0, param=None
# 0 - (297, 272), flags=0, param=None
# 0 - (235, 278), flags=0, param=None
# 0 - (198, 279), flags=0, param=None
# 0 - (194, 279), flags=0, param=None
# 0 - (170, 279), flags=0, param=None
# 0 - (166, 279), flags=0, param=None
# 0 - (165, 279), flags=0, param=None
# 0 - (164, 279), flags=0, param=None
# 0 - (164, 278), flags=0, param=None
# 0 - (162, 274), flags=0, param=None
# 0 - (161, 272), flags=0, param=None
# 0 - (152, 252), flags=0, param=None
# 0 - (145, 239), flags=0, param=None
# 0 - (144, 237), flags=0, param=None
# 0 - (140, 228), flags=0, param=None
# 0 - (139, 219), flags=0, param=None
# 0 - (138, 212), flags=0, param=None
# 0 - (138, 206), flags=0, param=None
# 0 - (140, 201), flags=0, param=None
# 0 - (141, 197), flags=0, param=None
# 0 - (143, 196), flags=0, param=None
# 0 - (144, 193), flags=0, param=None
# 0 - (146, 192), flags=0, param=None
# 0 - (149, 191), flags=0, param=None
# 0 - (152, 190), flags=0, param=None
# 0 - (156, 191), flags=0, param=None
# 0 - (162, 193), flags=0, param=None
# 0 - (163, 195), flags=0, param=None
# 0 - (165, 196), flags=0, param=None
# 0 - (173, 201), flags=0, param=None
# 0 - (174, 202), flags=0, param=None
# 0 - (176, 203), flags=0, param=None
# 0 - (178, 205), flags=0, param=None
# 0 - (188, 213), flags=0, param=None
# 0 - (202, 226), flags=0, param=None
# 0 - (204, 228), flags=0, param=None
# 0 - (206, 230), flags=0, param=None
# 0 - (208, 232), flags=0, param=None
# 0 - (220, 244), flags=0, param=None
# 0 - (231, 255), flags=0, param=None
# 0 - (234, 257), flags=0, param=None
# 0 - (242, 267), flags=0, param=None
# 0 - (243, 268), flags=0, param=None
# 0 - (244, 269), flags=0, param=None
# 0 - (248, 275), flags=0, param=None
# 0 - (250, 279), flags=0, param=None
# 0 - (250, 281), flags=0, param=None
# 0 - (251, 283), flags=0, param=None
# 0 - (251, 284), flags=0, param=None
# 0 - (251, 285), flags=0, param=None
# 0 - (251, 287), flags=0, param=None
# 0 - (251, 290), flags=0, param=None
# 0 - (251, 291), flags=0, param=None
# 0 - (250, 294), flags=0, param=None
# 0 - (246, 298), flags=0, param=None
# 0 - (246, 299), flags=0, param=None
# 0 - (238, 304), flags=0, param=None
# 0 - (236, 305), flags=0, param=None
# 0 - (223, 308), flags=0, param=None
# 0 - (206, 309), flags=0, param=None
# 0 - (203, 309), flags=0, param=None
# 0 - (201, 309), flags=0, param=None
# 0 - (198, 309), flags=0, param=None
# 0 - (195, 309), flags=0, param=None
# 0 - (192, 309), flags=0, param=None
# 0 - (164, 305), flags=0, param=None
# 0 - (154, 302), flags=0, param=None
# 0 - (147, 298), flags=0, param=None
# 0 - (143, 295), flags=0, param=None
# 0 - (143, 294), flags=0, param=None
# 0 - (141, 291), flags=0, param=None
# 0 - (140, 290), flags=0, param=None
# 0 - (139, 288), flags=0, param=None
# 0 - (139, 287), flags=0, param=None
# 0 - (139, 286), flags=0, param=None
# 0 - (138, 283), flags=0, param=None
# 0 - (138, 282), flags=0, param=None
# 0 - (137, 281), flags=0, param=None
# 0 - (137, 279), flags=0, param=None
# 0 - (136, 276), flags=0, param=None
# 0 - (135, 275), flags=0, param=None
# 0 - (135, 272), flags=0, param=None
# 0 - (134, 262), flags=0, param=None
# 0 - (134, 261), flags=0, param=None
# 0 - (134, 256), flags=0, param=None
# 0 - (134, 255), flags=0, param=None
# 0 - (134, 247), flags=0, param=None
# 0 - (138, 240), flags=0, param=None
# 0 - (140, 236), flags=0, param=None
# 0 - (141, 234), flags=0, param=None
# 1 - (141, 234), flags=1, param=None
# 0 - (141, 235), flags=1, param=None
# 0 - (136, 238), flags=1, param=None
# 0 - (117, 248), flags=1, param=None
# 0 - (96, 255), flags=1, param=None
# 0 - (93, 256), flags=1, param=None
# 0 - (68, 262), flags=1, param=None
# 0 - (65, 263), flags=1, param=None
# 0 - (63, 263), flags=1, param=None
# 0 - (54, 265), flags=1, param=None
# 0 - (44, 267), flags=1, param=None
# 0 - (35, 269), flags=1, param=None
# 0 - (34, 270), flags=1, param=None
# 0 - (33, 270), flags=1, param=None
# 0 - (31, 270), flags=1, param=None
# 0 - (30, 268), flags=1, param=None
# 0 - (27, 266), flags=1, param=None
# 0 - (26, 263), flags=1, param=None
# 0 - (25, 262), flags=1, param=None
# 0 - (24, 259), flags=1, param=None
# 0 - (26, 250), flags=1, param=None
# 0 - (27, 248), flags=1, param=None
# 0 - (30, 238), flags=1, param=None
# 0 - (31, 236), flags=1, param=None
# 0 - (35, 226), flags=1, param=None
# 0 - (35, 225), flags=1, param=None
# 0 - (40, 212), flags=1, param=None
# 0 - (40, 211), flags=1, param=None
# 0 - (43, 203), flags=1, param=None
# 0 - (44, 201), flags=1, param=None
# 0 - (44, 200), flags=1, param=None
# 0 - (48, 189), flags=1, param=None
# 0 - (52, 181), flags=1, param=None
# 0 - (52, 180), flags=1, param=None
# 0 - (56, 171), flags=1, param=None
# 0 - (59, 163), flags=1, param=None
# 0 - (61, 159), flags=1, param=None
# 0 - (62, 156), flags=1, param=None
# 0 - (62, 155), flags=1, param=None
# 0 - (63, 155), flags=1, param=None
# 4 - (63, 155), flags=1, param=None
# 0 - (66, 156), flags=0, param=None
# 0 - (67, 158), flags=0, param=None
# 0 - (68, 158), flags=0, param=None
# 0 - (69, 159), flags=0, param=None
# 0 - (71, 160), flags=0, param=None
# 0 - (72, 161), flags=0, param=None
# 0 - (77, 161), flags=0, param=None
# 0 - (81, 161), flags=0, param=None
# 0 - (167, 169), flags=0, param=None
# 0 - (289, 182), flags=0, param=None
# 0 - (441, 45), flags=0, param=None
# 0 - (437, 46), flags=0, param=None
# 0 - (414, 49), flags=0, param=None
# 0 - (381, 54), flags=0, param=None
# 0 - (347, 61), flags=0, param=None
# 0 - (321, 67), flags=0, param=None
# 0 - (317, 68), flags=0, param=None
# 0 - (301, 74), flags=0, param=None
# 0 - (291, 78), flags=0, param=None
# 0 - (287, 81), flags=0, param=None
# 0 - (285, 83), flags=0, param=None
# 0 - (284, 84), flags=0, param=None
# 1 - (284, 84), flags=1, param=None
# 0 - (284, 85), flags=1, param=None
# 4 - (284, 85), flags=1, param=None

# %%
#Trackbar para cambiar un eje de color
import cv2 as cv #BGR
import numpy as np

def trackbar(x):
    img[:, :, 2] = x
    cv.imshow('Mapa de Colores', img)

img = np.zeros((256, 256, 3), dtype=np.uint8)
for i in range(256):
    img[i, :, 0] = i
    img[:, i, 1] = i
    
cv.imshow('Mapa de Colores', img)

cv.createTrackbar('red', 'Mapa de Colores', 0, 255, trackbar)

cv.waitKey(0)
cv.destroyAllWindows()
